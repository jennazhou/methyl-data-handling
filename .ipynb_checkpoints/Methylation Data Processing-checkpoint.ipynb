# cg10488260              0.683338  ...              0.373133
# cg14273923              0.707219  ...              0.314656
# cg07587934              0.702442  ...              0.819448
# cg16855331              0.520328  ...              0.395179
#
#             X202995740078_R06C01  X202995740078_R07C01  X202995740078_R08C01  \
# ID_REF
# cg21870274              0.745360              0.750678              0.730141
# cg09499020              0.246794              0.205696              0.267445
# cg16535257              0.326582              0.241612              0.254309
# cg00168193              0.888991              0.881488              0.849838
# cg06325811              0.250433              0.215284              0.203567
# ...                          ...                   ...                   ...
# cg08265308              0.444347              0.975251              0.471873
# cg10488260              0.367859              0.763030              0.419255
# cg14273923              0.326333              0.768300              0.315643
# cg07587934              0.874524              0.722067              0.861921
# cg16855331              0.441209              0.382296              0.443635
#
#             X202995740086_R01C01  X202995740086_R04C01  X202995740086_R05C01  \
# ID_REF
# cg21870274              0.701641              0.784990              0.621896
# cg09499020              0.189799              0.249763              0.336476
# cg16535257              0.206012              0.212837              0.494311
# cg00168193              0.889427              0.851649              0.896408
# cg06325811              0.221526              0.221724              0.199937
# ...                          ...                   ...                   ...
# cg08265308              0.976447              0.491150              0.979743
# cg10488260              0.839747              0.405757              0.902550
# cg14273923              0.678554              0.307932              0.638683
# cg07587934              0.702745              0.762072              0.749422
# cg16855331              0.421434              0.510030              0.368019
#
#             X202995740086_R06C01  X202995740086_R07C01  X202995740086_R08C01
# ID_REF
# cg21870274              0.791403              0.805270              0.797593
# cg09499020              0.226000              0.241351              0.267494
# cg16535257              0.280269              0.308469              0.368667
# cg00168193              0.884844              0.916529              0.883041
# cg06325811              0.231084              0.240375              0.200764
# ...                          ...                   ...                   ...
# cg08265308              0.448790              0.469670              0.975101
# cg10488260              0.402768              0.357252              0.553329
# cg14273923              0.294244              0.320982              0.585755
# cg07587934              0.839330              0.879164              0.693731
# cg16855331              0.373857              0.491273              0.529708
#
# [766285 rows x 460 columns]

# %%
result = pd.concat([ppmi, propag_ageing], axis=1, join='inner', ignore_index=False)
result = result.rename_axis("Feature")
# result = result.rename_axis("Sample ID", axis="columns")
# result = result.transpose()
result.index.values.size

#Table of the common features used in both datasets
# Out:
# 764345

# %%
common_genes = result.index.values
common_genes
# Out:
# array(['cg21870274', 'cg09499020', 'cg16535257', ..., 'cg10488260',
#        'cg07587934', 'cg16855331'], dtype=object)

# %%
del_features = pd.read_csv('../datasets/annot_info.csv')
del_features
# Out:
#         Unnamed: 0           ID_REF             Name  AddressA_ID  \
# 0                1       cg00000029       cg00000029     40668283
# 1                2       cg00000103       cg00000103     76703527
# 2                3       cg00000109       cg00000109     39798525
# 3                4       cg00000155       cg00000155     22679178
# 4                5       cg00000158       cg00000158     33624521
# ...            ...              ...              ...          ...
# 867862      866453    ch.21.788740F    ch.21.788740F     82691238
# 867863      866499  ch.22.17803970R  ch.22.17803970R     96780498
# 867864      866525  ch.22.30020508R  ch.22.30020508R     85799208
# 867865      866926  ch.4.154120390F  ch.4.154120390F      6653827
# 867866      867805  ch.X.153018199F  ch.X.153018199F     82690326
#
#                                          AlleleA_ProbeSeq  AddressB_ID  \
# 0       AACTATACTAACRAAAAAATATCCAAAAAACACTAACRTATAAAAA...          NaN
# 1       AACTTAACTTACAACCAATTATCCCAACRATTTCAACTAATAATAT...          NaN
# 2       CAATACTAACAAACACATATACCCCCCCACAAATCTTAACTTCTAA...          NaN
# 3       AATAAAAAACCACTACACCCAACCTAAACATAATAATTAAATATTC...          NaN
# 4       AACTAAACATTCCRTATTATTTACTTCAAACTATTCTCATTTTCCC...          NaN
# ...                                                   ...          ...
# 867862  CTAACTCTTCCCTCAAAACAACTACCTCTAAATTACAACTACCAAA...          NaN
# 867863  CAACCAAAATTAAAATTAATTCACCAAACCAAACTCAATAACTCAT...          NaN
# 867864  ATCCTCTAACTCTTAACTTAATCTACCCTATAAATTACACCCTAAA...          NaN
# 867865  CAACCAACAACCTCATTTAAACTCTTAAACCTTTAAAAAACAAATC...          NaN
# 867866  TCAACTCTTTCTCCTAAACTATTCCAAAACCTTACAACTAACCTTA...          NaN
#
#        AlleleB_ProbeSeq Infinium_Design_Type Next_Base Color_Channel  ...  \
# 0                   NaN                   II       NaN           NaN  ...
# 1                   NaN                   II       NaN           NaN  ...
# 2                   NaN                   II       NaN           NaN  ...
# 3                   NaN                   II       NaN           NaN  ...
# 4                   NaN                   II       NaN           NaN  ...
# ...                 ...                  ...       ...           ...  ...
# 867862              NaN                   II       NaN           NaN  ...
# 867863              NaN                   II       NaN           NaN  ...
# 867864              NaN                   II       NaN           NaN  ...
# 867865              NaN                   II       NaN           NaN  ...
# 867866              NaN                   II       NaN           NaN  ...
#
#        Chromosome_36  Coordinate_36  \
# 0                 16     52025613.0
# 1                  4     73689050.0
# 2                  3    173398731.0
# 3                  7      2557091.0
# 4                  9     94050376.0
# ...              ...            ...
# 867862           NaN            NaN
# 867863           NaN            NaN
# 867864           NaN            NaN
# 867865           NaN            NaN
# 867866           NaN            NaN
#
#                                                SNP_ID  SNP_DISTANCE  \
# 0                                                 NaN           NaN
# 1                   rs16848262;rs146966574;rs61513989       1;23;27
# 2       rs572345338;rs9864492;rs553441475;rs183505630    2;17;23;24
# 3                                         rs116384860             0
# 4                               rs78176522;rs80089624          0;38
# ...                                               ...           ...
# 867862                                            NaN           NaN
# 867863                                            NaN           NaN
# 867864                                            NaN           NaN
# 867865                                            NaN           NaN
# 867866                                            NaN           NaN
#
#                    SNP_MinorAlleleFrequency Random_Loci   X   Class  \
# 0                                       NaN         NaN NaN  ClassA
# 1                0.024960;0.000200;0.069090         NaN NaN  ClassD
# 2       0.000200;0.009784;0.000599;0.003594         NaN NaN  ClassC
# 3                                  0.009784         NaN NaN  ClassC
# 4                         0.000200;0.012380         NaN NaN  ClassC
# ...                                     ...         ...  ..     ...
# 867862                                  NaN         NaN NaN  ClassA
# 867863                                  NaN         NaN NaN  ClassA
# 867864                                  NaN         NaN NaN  ClassA
# 867865                                  NaN         NaN NaN  ClassA
# 867866                                  NaN         NaN NaN  ClassA
#
#                                      BOP n.CpG
# 0        chr16:53468284-53469209*N_Shore   9.0
# 1                                    NaN   NaN
# 2                                    NaN   NaN
# 3                                    NaN   NaN
# 4                                    NaN   NaN
# ...                                  ...   ...
# 867862   chr21:46961668-46963078*S_Shore   7.0
# 867863   chr22:19418745-19420237*S_Shelf   1.0
# 867864   chr22:31686636-31687371*S_Shelf   1.0
# 867865  chr4:153897452-153897749*S_Shelf   2.0
# 867866  chrX:153362568-153363473*S_Shore   1.0
#
# [867867 rows x 51 columns]

# %%
del_features['ID_REF'][0][:2]
# print(del_features['CHR'].unique())
# del_features[(del_features['ID_REF'].str[:2]) == 'cg']
X_chr = del_features[del_features['CHR'] == 'X']
print("Size of sex genes with X_chr:" + str(X_chr.size))
Y_chr = del_features[del_features['CHR'] == 'Y']
print("Size of sex genes with Y_chr:" + str(Y_chr.size))
sex_genes = pd.concat([X_chr, Y_chr])
sex_genes = sex_genes['ID_REF'].values
sex_genes
# Out:
# Size of sex genes with X_chr:976140
# Size of sex genes with Y_chr:28611
# array(['cg00004031', 'cg00005617', 'cg00006815', ..., 'cg27545697',
#        'cg27578568', 'cg27611726'], dtype=object)

# %%
impeding_genes = pd.read_table('../datasets/EPIC_probes_to_be_filtered.txt', delim_whitespace=True)
impeding_genes = impeding_genes['EPIC_probes_to_be_filtered'].values
print('Number of common genes:' + str(common_genes.size))
print('Number of impeding genes:' + str(impeding_genes.size))
print('Number of sex genes:' + str(sex_genes.size))
# Out:
# Number of common genes:764345
# Number of impeding genes:99360
# Number of sex genes:19701
# Number of the remaining genes after removing impeding and sex genes: 645284

# %%
set1 = set(common_genes.flatten())
set2 = set(sex_genes.flatten())
# print(len(set1))
# # final_genes.size
# set2 = set(impeding_genes.flatten())
# print(len(set2))
# final_genes = set1.difference(set2)
# # final_genes
# print(len(final_genes))
df1 = pd.DataFrame(data=common_genes[:], columns=['Features'])
# print(df1)
df2 = pd.DataFrame(data=impeding_genes[:], columns=['Features'])
# print(df2)
df3 = pd.DataFrame(data=sex_genes[:], columns=['Features'])
print(df3.shape)
res = pd.merge(df1, df3, how='inner', on=['Features'])
print('Number of sex genes used in PPMI is: ' + str(res.shape[0]))
final_genes = np.array(set1.difference(set2))
type(final_genes)
# Out:
# (19701, 1)
# Number of sex genes used in PPMI is: 16677
# numpy.ndarray

# %%
selected_ppmi = ppmi.loc[final_genes]
selected_ppmi = selected_ppmi.transpose()
selected_ppmi.index
# Out:
# Index(['200973410159_R03C01', '200991620021_R01C01', '200991620021_R03C01',
#        '200989060105_R03C01', '200989060135_R07C01', '200989060162_R04C01',
#        '200973410167_R04C01', '200973410143_R01C01', '200973410143_R06C01',
#        '200973410167_R05C01',
#        ...
#        '200989060089_R02C01', '200989060089_R01C01', '200989060089_R04C01',
#        '200973410143_R08C01', '200973410143_R07C01', '200989060089_R03C01',
#        '200989060150_R04C01', '200989060150_R05C01', '200989060150_R06C01',
#        '200991620049_R08C01'],
#       dtype='object', length=524)

# %%
# result_temp[result_temp.index=='cg16535257']
# result_temp[result_temp['X201438350023_R01C01']==0.277931]

# %%
groups = pd.read_csv('../datasets/PROPAG-AGEING/propag_phenotypes.csv')[['Colname', 'Group']]
groups = groups.dropna()
groups
# Out:
#                   Colname           Group
# 0    X201438350023_R01C01  CTR_GENERAL_KI
# 1    X201438350023_R03C01            CENT
# 2    X201438350023_R04C01     CTR_GENERAL
# 3    X201438350023_R05C01     CTR_GENERAL
# 4    X201438350023_R06C01  CTR_GENERAL_KI
# ..                    ...             ...
# 453  X202995740078_R08C01     CTR_GENERAL
# 454  X202995740086_R01C01  CTR_GENERAL_KI
# 456  X202995740086_R05C01            PD_A
# 457  X202995740086_R06C01     CTR_GENERAL
# 459  X202995740086_R08C01     CTR_GENERAL
#
# [409 rows x 2 columns]

# %%
cnt = groups.groupby('Group').count()
print(cnt)
# Out:
#                    Colname
# Group
# CENT                    28
# CENT_OS                 19
# CTR_GENERAL            132
# CTR_GENERAL_KI          70
# PD_A                     1
# PD_D                    79
# PD_TWIN_INCIDENT        60
# PD_TWIN_PREVALENT       20

# %%
classPD_pro = pd.DataFrame({"Class": ["Control", "PD"],
                          "Number of patients": [0, 0]})
classPD_pro
# Out:
#      Class  Number of patients
# 0  Control                   0
# 1       PD                   0

# %%
pd.read_csv('../datasets/PPMI/EstimateCellCounts_PPMI_EPICn524final030618.csv')
# Out:
#         Sentrix_position      CD8T      CD4T        NK     Bcell      Mono  \
# 0    200973410159_R03C01  0.098871  0.158745  0.014156  0.050155  0.056538
# 1    200991620021_R01C01  0.052004  0.163162  0.045057  0.047703  0.066119
# 2    200991620021_R03C01  0.092307  0.170316  0.000000  0.084111  0.103215
# 3    200989060105_R03C01  0.145791  0.046767  0.076241  0.052520  0.085288
# 4    200989060135_R07C01  0.017866  0.062666  0.029187  0.026347  0.104616
# ..                   ...       ...       ...       ...       ...       ...
# 519  200989060089_R03C01  0.103612  0.124401  0.135060  0.035850  0.119331
# 520  200989060150_R04C01  0.003675  0.170421  0.086015  0.050823  0.084183
# 521  200989060150_R05C01  0.064991  0.108611  0.032823  0.072779  0.093619
# 522  200989060150_R06C01  0.140840  0.089634  0.044094  0.057892  0.083403
# 523  200991620049_R08C01  0.059249  0.116426  0.021142  0.053487  0.134621
#
#          Gran
# 0    0.657973
# 1    0.626899
# 2    0.564232
# 3    0.624211
# 4    0.734208
# ..        ...
# 519  0.491491
# 520  0.620211
# 521  0.649436
# 522  0.610717
# 523  0.629855
#
# [524 rows x 7 columns]

# %%
patinfo = pd.read_csv('../datasets/PPMI/Patient_Status.csv', index_col='PATNO')
# patinfo.sort_values(by='PATNO')
patinfo.index.astype('int64')
patinfo
# Out:
#       RECRUITMENT_CAT IMAGING_CAT ENROLL_DATE ENROLL_CAT ENROLL_STATUS  \
# PATNO
# 10362        PRODROMA    PRODROMA         NaN        NaN      Excluded
# 10405        PRODROMA    PRODROMA         NaN        NaN      Excluded
# 10496        PRODROMA    PRODROMA         NaN        NaN      Excluded
# 10606        PRODROMA    no image         NaN        NaN      Declined
# 10662        PRODROMA    PRODROMA         NaN        NaN      Excluded
# ...               ...         ...         ...        ...           ...
# 92490        PRODROMA    PRODROMA     01/2015   PRODROMA      Enrolled
# 92516        PRODROMA    PRODROMA         NaN        NaN      Excluded
# 92560        PRODROMA    PRODROMA         NaN        NaN      Excluded
# 92834        PRODROMA    PRODROMA     02/2015   PRODROMA      Enrolled
# 92876        PRODROMA    PRODROMA         NaN        NaN      Excluded
#
#       DESCRP_CAT STATUS_DATE
# PATNO
# 10362        HYP     08/2013
# 10405        HYP     09/2014
# 10496        HYP     06/2013
# 10606        HYP     08/2013
# 10662        HYP     06/2014
# ...          ...         ...
# 92490        HYP     01/2015
# 92516        HYP     11/2014
# 92560        HYP     06/2014
# 92834        HYP     02/2015
# 92876        HYP     11/2014
#
# [2234 rows x 7 columns]

# %%
patno = pd.read_csv('../datasets/PPMI/PPMI_Meth_n524_for_LONI030718.txt',  sep="\t", header=None)
patno.columns = ["PATNO", "Sentrix ID", "Sentrix Position"]
patno.drop([0], axis=0, inplace=True)
patno.set_index(pd.to_numeric(patno["PATNO"]), inplace=True)
patno.drop(columns=["PATNO"], inplace=True)
patno
# Out:
#          Sentrix ID Sentrix Position
# PATNO
# 3000   200973410159           R03C01
# 3001   200991620021           R01C01
# 3002   200991620021           R03C01
# 3003   200989060105           R03C01
# 3004   200989060135           R07C01
# ...             ...              ...
# 3570   200973410143           R07C01
# 3656   200989060089           R03C01
# 4058   200989060150           R04C01
# 4059   200989060150           R05C01
# 4093   200989060150           R06C01
#
# [524 rows x 2 columns]

# %%
result = pd.concat([patinfo, patno], axis=1, join='inner', ignore_index=False)[['ENROLL_CAT']]
result.reset_index("PATNO",inplace=True)
ppmi_classes_group = result.groupby('ENROLL_CAT').count()
ppmi_classes_group.index
ppmi_classes_group.rename(columns={"PATNO":"Number of patients"}, inplace=True)
ppmi_classes_group.rename_axis("Classes of patients")
# ppmi_classes_group = ppmi_classes.loc[['HC', 'PD']]
ppmi_classes_group
# Out:
#             Number of patients
# ENROLL_CAT
# HC                         134
# PD                         330
# SWEDD                       54

# %%
ppmi_labels = result["ENROLL_CAT"].values
patno["ENROLL_CAT"] = ppmi_labels
#ppmi_patinfo contains 524 rows, including SWEDD
ppmi_patinfo = patno
#ppmi_patno_woswedd only contains 420 rows
ppmi_patno_woswedd = patno[patno["ENROLL_CAT"]!="SWEDD"]
#sentrix_position combines two columns to form the index of the big ppmi table
sentrix_position = ppmi_patno_woswedd["Sentrix ID"]+"_"+ppmi_patno_woswedd["Sentrix Position"]
ppmi_patno_woswedd["Sentrix_position"] = sentrix_position
ppmi_patno_woswedd
#Now, we want a new dataframe that contains only Sentrix_position as index and ENROLL_CAT as labels which are to be matched with original ppmi table
ppmi_classes = pd.DataFrame(index=ppmi_patno_woswedd["Sentrix_position"], data={"Category":ppmi_patno_woswedd["ENROLL_CAT"].values})
ppmi_classes

##need to check whether the Sentrix_position index formed here is equal to the original index column in the ppmi data
## need to debug here: Category contains nan values ?????
# Out:
# True
# /local/sdd/rz296/miniconda3/envs/partII/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
patno_seq = ppmi_patno_classes.index
sub_patinfo = patinfo.loc[patno_seq]
sub_patinfo
# Out:
#       RECRUITMENT_CAT IMAGING_CAT ENROLL_DATE ENROLL_CAT ENROLL_STATUS  \
# PATNO
# 3000               HC          HC     02/2011         HC      Enrolled
# 3001               PD          PD     03/2011         PD      Enrolled
# 3002               PD          PD     03/2011         PD      Enrolled
# 3003               PD          PD     04/2011         PD      Enrolled
# 3004               HC          HC     04/2011         HC      Enrolled
# ...               ...         ...         ...        ...           ...
# 3565               HC          HC     06/2011         HC      Enrolled
# 3570               HC          HC     06/2011         HC      Enrolled
# 4058               PD          PD     07/2012         PD      Enrolled
# 4059               PD          PD     07/2012         PD      Enrolled
# 4093               PD          PD     08/2012         PD      Enrolled
#
#       DESCRP_CAT STATUS_DATE
# PATNO
# 3000         NaN     02/2011
# 3001         NaN     03/2011
# 3002         NaN     03/2011
# 3003         NaN     04/2011
# 3004         NaN     04/2011
# ...          ...         ...
# 3565         NaN     06/2011
# 3570         NaN     06/2011
# 4058         NaN     07/2012
# 4059         NaN     07/2012
# 4093         NaN     08/2012
#
# [470 rows x 7 columns]
